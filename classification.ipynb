# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("phones.csv")

# %% [markdown]
# # Data analysis

# %%
print("Shape of the dataset is :{}".format(data.shape))
data.head()
# Out:
# Shape of the dataset is :(2000, 21)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
data.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data.notna().all(axis=1)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1995    True
# 1996    True
# 1997    True
# 1998    True
# 1999    True
# Length: 2000, dtype: bool

# %%
indexes = data.select_dtypes(include="number").columns

# %%
for i in indexes:
       fig, (ax_box, ax_dist,) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.2, .8)})
       sns.boxplot(x=i, data=data, color="#760445", ax=ax_box)
       sns.histplot(x=i, data=data, color="#78A2CC", ax=ax_dist, kde=True,line_kws={"linewidth":4})
       plt.axvline(data[i].mean(), color="#760445", linewidth=4)
       plt.show()

# %%
plt.figure(figsize=(14,8))
sns.heatmap(round(data.corr(),2), annot=True, cmap="BuPu")
plt.title("Correlation relationship", size=15)
plt.xticks(rotation=45)
plt.show()

# %%
haz = sns.countplot(x="price_range", data=data, palette="magma")
haz.bar_label(haz.containers[0])
plt.title("Original dataset - price range classes")
plt.show()

# %%
X = data.drop(columns="price_range")
Y = data["price_range"]

# %%
# Splitting the data into Training & Testing
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X, Y)

# %%
print(xTrain.shape)
print(xTest.shape)
print(yTrain.shape) 
print(yTest.shape)
# Out:
# (1500, 20)
# (500, 20)
# (1500,)
# (500,)

# %%
# Importing metrics
from sklearn.metrics import classification_report, recall_score, precision_score, f1_score, roc_auc_score, log_loss, matthews_corrcoef, plot_confusion_matrix
from sklearn.model_selection import cross_val_score, cross_validate

# %%
results = pd.DataFrame(columns=["Model","TrainScore","TestScore","PrecisionAvg", "RecallAvg", "F1Avg", "RocAuc", "MCC"])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Defining a function for metrics.
# Logistic Regression
# GaussianNB
# DecisionTreeClassifier
# RandomForestClassifier
# KNN
# SVC
# XGB
def classificationmodel(test):
    test.fit(xTrain, yTrain)
    scoretrain = test.score(xTrain, yTrain)
    scoretest = test.score(xTest, yTest)
    print("Score of the training dataset:", test.score(xTrain, yTrain))
    print("Score of the testing dataset:", test.score(xTest, yTest))
    print("Log-loss of the testing dataset:", log_loss(yTest, test.predict_proba(xTest)))
    print("ROC-AUC score of the testing dataset:", roc_auc_score(yTest, test.predict_proba(xTest), multi_class="ovr"))
    print("Matthews correlation coefficient of the testing dataset:", matthews_corrcoef(yTest, test.predict(xTest)), "\n")
    print("Classification report on Testing split:")
    print(classification_report(yTest, test.predict(xTest)))
    plot_confusion_matrix(test, xTest, yTest)
    if len(results.index) == 0:
        results.loc[len(results.index)] = ["LR", scoretrain, scoretest, precision_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"), recall_score(y_true=yTest, y_pred=test.predict(xTest), average='macro'), f1_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"), roc_auc_score(yTest, test.predict_proba(xTest), multi_class="ovr"), matthews_corrcoef(yTest, test.predict(xTest))]
    elif len(results.index) == 1:
        results.loc[len(results.index)] = ["GNB", scoretrain, scoretest, precision_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"), recall_score(y_true=yTest, y_pred=test.predict(xTest), average='macro'), f1_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"),roc_auc_score(yTest, test.predict_proba(xTest), multi_class="ovr"), matthews_corrcoef(yTest, test.predict(xTest))]
    elif len(results.index) == 2:
        results.loc[len(results.index)] = ["DTC", scoretrain, scoretest, precision_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"), recall_score(y_true=yTest, y_pred=test.predict(xTest), average='macro'), f1_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"),roc_auc_score(yTest, test.predict_proba(xTest), multi_class="ovr"), matthews_corrcoef(yTest, test.predict(xTest))]
    elif len(results.index) == 3:
        results.loc[len(results.index)] = ["RFC", scoretrain, scoretest, precision_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"), recall_score(y_true=yTest, y_pred=test.predict(xTest), average='macro'), f1_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"),roc_auc_score(yTest, test.predict_proba(xTest), multi_class="ovr"), matthews_corrcoef(yTest, test.predict(xTest))]
    elif len(results.index) == 4:
        results.loc[len(results.index)] = ["KNN", scoretrain, scoretest, precision_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"), recall_score(y_true=yTest, y_pred=test.predict(xTest), average='macro'), f1_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"),roc_auc_score(yTest, test.predict_proba(xTest), multi_class="ovr"), matthews_corrcoef(yTest, test.predict(xTest))]
    elif len(results.index) == 5:
        results.loc[len(results.index)] = ["GBC", scoretrain, scoretest, precision_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"), recall_score(y_true=yTest, y_pred=test.predict(xTest), average='macro'), f1_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"),roc_auc_score(yTest, test.predict_proba(xTest), multi_class="ovr"), matthews_corrcoef(yTest, test.predict(xTest))]
    elif len(results.index) == 6:
        results.loc[len(results.index)] = ["XGB", scoretrain, scoretest, precision_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"), recall_score(y_true=yTest, y_pred=test.predict(xTest), average='macro'), f1_score(y_true=yTest, y_pred=test.predict(xTest), average="macro"),roc_auc_score(yTest, test.predict_proba(xTest), multi_class="ovr"), matthews_corrcoef(yTest, test.predict(xTest))]

def crossval(m):
    print("Cross-validation on Training split (mean, cv=5):")
    for i in ["accuracy", "roc_auc_ovr"]:
        print(i.upper())
        print(cross_val_score(m, xTrain, yTrain, scoring=i).mean())
    print("\n")

# %% [markdown]
# # Trying the first two models

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
crossval(LR)
classificationmodel(LR)
# Out:
# Cross-validation on Training split (mean, cv=5):
# ACCURACY
# 0.6366666666666666
# ROC_AUC_OVR
# 0.8786692803904886
#
#
# Score of the training dataset: 0.636
# Score of the testing dataset: 0.636
# Log-loss of the testing dataset: 0.7687454236923276
# ROC-AUC score of the testing dataset: 0.8831045588742346
# Matthews correlation coefficient of the testing dataset: 0.5165488147512138
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.78       126
#            1       0.58      0.50      0.54       137
#            2       0.51      0.52      0.52       117
#            3       0.65      0.78      0.71       120
#
#     accuracy                           0.64       500
#    macro avg       0.64      0.64      0.63       500
# weighted avg       0.64      0.64      0.63       500

# %%
from sklearn.naive_bayes import GaussianNB
GSS = GaussianNB()
crossval(GSS)
classificationmodel(GSS)
# Out:
# Cross-validation on Training split (mean, cv=5):
# ACCURACY
# 0.7993333333333335
# ROC_AUC_OVR
# 0.9499444501546849
#
#
# Score of the training dataset: 0.8153333333333334
# Score of the testing dataset: 0.794
# Log-loss of the testing dataset: 0.46737553687136374
# ROC-AUC score of the testing dataset: 0.9512436057068465
# Matthews correlation coefficient of the testing dataset: 0.725347049078044
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       126
#            1       0.75      0.72      0.74       137
#            2       0.70      0.66      0.68       117
#            3       0.84      0.90      0.87       120
#
#     accuracy                           0.79       500
#    macro avg       0.79      0.79      0.79       500
# weighted avg       0.79      0.79      0.79       500

# %% [markdown]
# # Feature engineering

# %%
def transformization(tran):
    global xTrain, yTrain
    if tran == "stand":
        print("You have selected Standardization.")
        from sklearn.preprocessing import StandardScaler
        xTrain, xTest, yTrain, yTest = train_test_split(X,Y)
        scal = StandardScaler()
        xTrain = scal.fit_transform(xTrain)
        xTest = scal.transform(xTest)
        xTrain = pd.DataFrame(xTrain, columns=X.columns)
        xTest = pd.DataFrame(xTest, columns=X.columns)

    elif tran == "norm":
        print("You have selected Normalization.")
        from sklearn.preprocessing import MinMaxScaler
        xTrain, xTest, yTrain, yTest = train_test_split(X,Y)
        norm = MinMaxScaler()
        xTrain = norm.fit_transform(xTrain)
        xTest = norm.transform(xTest)
        xTrain = pd.DataFrame(xTrain, columns=X.columns)
        xTest = pd.DataFrame(xTest, columns=X.columns)
        
    else:
        print("You didn't select any type of transformation of features, proceeding with the original dataset.")


def classdist(classd):
    global xTrain, yTrain
    if classd == "over":
        print("You have selected Oversampling.")
        from imblearn.over_sampling import RandomOverSampler
        ros = RandomOverSampler(sampling_strategy="minority")
        xTrain, yTrain = ros.fit_resample(xTrain, yTrain)
    elif classd == "smote":
        print("You have selected SMOTE.")
        from imblearn.over_sampling import SMOTE
        smote = SMOTE(random_state = 42)
        xTrain, yTrain = smote.fit_resample(xTrain, yTrain)
    elif classd == "under":
        print("You have selected Undersampling.")
        from imblearn.under_sampling import RandomUnderSampler
        ros = RandomUnderSampler(sampling_strategy="majority")
        xTrain, yTrain = ros.fit_resample(xTrain, yTrain)
    else:
        print("You didn't select any class sampling technique, proceeding with the original dataset.")

# %%
results = pd.DataFrame(columns=["Model","TrainScore","TestScore","PrecisionAvg", "RecallAvg", "F1Avg", "RocAuc", "MCC"])

# %%
# TRANSFORMATION OF FEATURES
# Standardization - "stand"
# Normalizazion - "norm"
# None - "none"
transformization("none")
# Out:
# You didn't select any type of transformation of features, proceeding with the original dataset.

# %%
# CLASS SAMPLING
# Oversampling - "over"
# SMOTE - "smote"
# Undersampling - "under"
# None - "none"
classdist("none")
# Out:
# You didn't select any class sampling technique, proceeding with the original dataset.

# %%
xTrain.head()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1531           1770     1          2.3         0   0       0           9
# 376            1899     1          0.6         0   0       0          26
# 54             1073     1          0.5         1   0       0          51
# 930            1558     1          2.4         0   0       1          27
# 874            1332     0          0.8         1   2       0          11
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 1531    0.6        183        6   5       1098      1373  3785    13    10
# 376     0.1        151        2   0         96       814   336    13    11
# 54      0.5        145        7   0        690       804  2908     6     0
# 930     0.1        146        1   1        120      1409  3598     9     2
# 874     0.5        187        2   4        758      1165  1285     5     0
#
#       talk_time  three_g  touch_screen  wifi
# 1531         14        1             0     1
# 376           4        1             0     1
# 54           18        0             1     0
# 930          12        1             0     1
# 874           9        1             1     0

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(12, 5), sharey=True)
haz = sns.countplot(x=yTrain, palette="magma", ax=ax1)
haz.bar_label(haz.containers[0])
plt.title("Training dataset - price range classes")
haz1 = sns.countplot(x=yTest, palette="magma", ax=ax2)
haz1.bar_label(haz1.containers[0])
ax1.title.set_text("Training dataset - price range classes")
ax2.title.set_text("Testing dataset - price range classes")
plt.show()

# %% [markdown]
# # ML models

# %%
# Linear Regression
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
from sklearn.model_selection import cross_val_score
crossval(LR)
classificationmodel(LR)
# Out:
# Cross-validation on Training split (mean, cv=5):
# ACCURACY
# 0.6366666666666666
# ROC_AUC_OVR
# 0.8786692803904886
#
#
# Score of the training dataset: 0.636
# Score of the testing dataset: 0.636
# Log-loss of the testing dataset: 0.7687454236923276
# ROC-AUC score of the testing dataset: 0.8831045588742346
# Matthews correlation coefficient of the testing dataset: 0.5165488147512138
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.78       126
#            1       0.58      0.50      0.54       137
#            2       0.51      0.52      0.52       117
#            3       0.65      0.78      0.71       120
#
#     accuracy                           0.64       500
#    macro avg       0.64      0.64      0.63       500
# weighted avg       0.64      0.64      0.63       500

# %%
# Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
GNB = GaussianNB()
crossval(GSS)
classificationmodel(GNB)
# Out:
# Cross-validation on Training split (mean, cv=5):
# ACCURACY
# 0.7993333333333335
# ROC_AUC_OVR
# 0.9499444501546849
#
#
# Score of the training dataset: 0.8153333333333334
# Score of the testing dataset: 0.794
# Log-loss of the testing dataset: 0.46737553687136374
# ROC-AUC score of the testing dataset: 0.9512436057068465
# Matthews correlation coefficient of the testing dataset: 0.725347049078044
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       126
#            1       0.75      0.72      0.74       137
#            2       0.70      0.66      0.68       117
#            3       0.84      0.90      0.87       120
#
#     accuracy                           0.79       500
#    macro avg       0.79      0.79      0.79       500
# weighted avg       0.79      0.79      0.79       500

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier()
crossval(DTC)
classificationmodel(DTC)
# Out:
# Cross-validation on Training split (mean, cv=5):
# ACCURACY
# 0.8373333333333333
# ROC_AUC_OVR
# 0.8879609682312726
#
#
# Score of the training dataset: 1.0
# Score of the testing dataset: 0.826
# Log-loss of the testing dataset: 6.00974709271446
# ROC-AUC score of the testing dataset: 0.8842191276183582
# Matthews correlation coefficient of the testing dataset: 0.7680062798139683
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88       126
#            1       0.81      0.77      0.79       137
#            2       0.76      0.77      0.77       117
#            3       0.88      0.86      0.87       120
#
#     accuracy                           0.83       500
#    macro avg       0.83      0.83      0.83       500
# weighted avg       0.83      0.83      0.83       500

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier()
crossval(RFC)
classificationmodel(RFC)
# Out:
# Cross-validation on Training split (mean, cv=5):
# ACCURACY
# 0.8773333333333333
# ROC_AUC_OVR
# 0.9773046025387842
#
#
# Score of the training dataset: 1.0
# Score of the testing dataset: 0.882
# Log-loss of the testing dataset: 0.529183161382618
# ROC-AUC score of the testing dataset: 0.9821097351529392
# Matthews correlation coefficient of the testing dataset: 0.8427654188484481
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       126
#            1       0.85      0.85      0.85       137
#            2       0.86      0.79      0.82       117
#            3       0.91      0.93      0.92       120
#
#     accuracy                           0.88       500
#    macro avg       0.88      0.88      0.88       500
# weighted avg       0.88      0.88      0.88       500

# %%
# K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
crossval(KNN)
classificationmodel(KNN)
# Out:
# Cross-validation on Training split (mean, cv=5):
# ACCURACY
# 0.916
# ROC_AUC_OVR
# 0.9884495942112028
#
#
# Score of the training dataset: 0.954
# Score of the testing dataset: 0.916
# Log-loss of the testing dataset: 0.3124753376628574
# ROC-AUC score of the testing dataset: 0.9890842305827869
# Matthews correlation coefficient of the testing dataset: 0.8880378221774502
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       126
#            1       0.91      0.90      0.90       137
#            2       0.90      0.85      0.88       117
#            3       0.93      0.94      0.93       120
#
#     accuracy                           0.92       500
#    macro avg       0.92      0.92      0.92       500
# weighted avg       0.92      0.92      0.92       500

# %%
# Gradien Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier()
crossval(GBC)
classificationmodel(GBC)
# Out:
# Cross-validation on Training split (mean, cv=5):
# ACCURACY
# 0.898
# ROC_AUC_OVR
# 0.9827319545741975
#
#
# Score of the training dataset: 0.9986666666666667
# Score of the testing dataset: 0.894
# Log-loss of the testing dataset: 0.2510652593937468
# ROC-AUC score of the testing dataset: 0.9872087174177494
# Matthews correlation coefficient of the testing dataset: 0.8586495644871366
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       126
#            1       0.88      0.85      0.87       137
#            2       0.87      0.85      0.86       117
#            3       0.93      0.93      0.93       120
#
#     accuracy                           0.89       500
#    macro avg       0.89      0.89      0.89       500
# weighted avg       0.89      0.89      0.89       500

# %%
# XGBoost Classifier
from xgboost import XGBClassifier
XGB = XGBClassifier()
crossval(XGB)
classificationmodel(XGB)
# Out:
# Cross-validation on Training split (mean, cv=5):
# ACCURACY
# 0.9053333333333333
# ROC_AUC_OVR
# 0.9873232701021356
#
#
# Score of the training dataset: 1.0
# Score of the testing dataset: 0.906
# Log-loss of the testing dataset: 0.24455144410112462
# ROC-AUC score of the testing dataset: 0.9901546213086561
# Matthews correlation coefficient of the testing dataset: 0.8745881153934344
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       126
#            1       0.89      0.88      0.88       137
#            2       0.89      0.87      0.88       117
#            3       0.94      0.93      0.94       120
#
#     accuracy                           0.91       500
#    macro avg       0.91      0.91      0.91       500
# weighted avg       0.91      0.91      0.91       500

# %% [markdown]
# # Results

# %%
results
# Out:
#   Model  TrainScore  TestScore  PrecisionAvg  RecallAvg     F1Avg    RocAuc  \
# 0    LR    0.636000      0.636      0.635099   0.638755  0.634332  0.883105
# 1   GNB    0.815333      0.794      0.790745   0.794393  0.792063  0.951244
# 2   DTC    1.000000      0.826      0.825740   0.826512  0.825781  0.884219
# 3   RFC    1.000000      0.882      0.881663   0.881513  0.880974  0.982110
# 4   KNN    0.954000      0.916      0.915621   0.915608  0.915306  0.989084
# 5   GBC    0.998667      0.894      0.893814   0.894487  0.893938  0.987209
# 6   XGB    1.000000      0.906      0.906355   0.906371  0.906243  0.990155
#
#         MCC
# 0  0.516549
# 1  0.725347
# 2  0.768006
# 3  0.842765
# 4  0.888038
# 5  0.858650
# 6  0.874588

# %%
results[["TrainScore","TestScore"]].plot(kind="bar", color=["#E14625","#06BBA3"])
plt.xticks(range(0,len(results["Model"])), results["Model"])
results["PrecisionAvg"].plot(c="#0E38CA", linewidth=3, secondary_y=True, label="PrecisionAvg")
results["RecallAvg"].plot(c="#A514DB", linewidth=3, secondary_y=True, label="RecallAvg")
plt.legend(loc="lower right")
plt.show()

# %%
print("K-NearestNeighbors didn't overfit and had good results.")
results[(results["TrainScore"] > 0.9) & (results["TestScore"] > 0.9) & (results["PrecisionAvg"] > 0.9) & (results["RecallAvg"] > 0.9)]
# Out:
# K-NearestNeighbors didn't overfit and had good results.
#   Model  TrainScore  TestScore  PrecisionAvg  RecallAvg     F1Avg    RocAuc  \
# 4   KNN       0.954      0.916      0.915621   0.915608  0.915306  0.989084
# 6   XGB       1.000      0.906      0.906355   0.906371  0.906243  0.990155
#
#         MCC
# 4  0.888038
# 6  0.874588

# %%
# Testing the best model on 5 different Dataset splits.
from sklearn import multiclass


knntab = pd.DataFrame(columns=["TryNo","TrainScore","TestScore","PrecisionAvg","RecallAvg","RocAuc"])
for i in range(1,6):
    xTrain, xTest, yTrain, yTest = train_test_split(X,Y)
    knn = KNeighborsClassifier()
    knn.fit(xTrain,yTrain)
    knntab.loc[len(knntab)] = [i, knn.score(xTrain,yTrain), knn.score(xTest,yTest), precision_score(y_true=yTest, y_pred=knn.predict(xTest), average="micro"), recall_score(y_true=yTest, y_pred=knn.predict(xTest), average="micro"), roc_auc_score(yTest, knn.predict_proba(xTest), multi_class="ovo")]
    if len(knntab) == 5:
        knntab.loc[len(knntab)] = ["Mean", knntab["TrainScore"].mean(axis=0), knntab["TestScore"].mean(axis=0), knntab["PrecisionAvg"].mean(axis=0), knntab["RecallAvg"].mean(axis=0), knntab["RocAuc"].mean(axis=0)]
knntab
# Out:
#   TryNo  TrainScore  TestScore  PrecisionAvg  RecallAvg    RocAuc
# 0   1.0    0.954000     0.9220        0.9220     0.9220  0.987640
# 1   2.0    0.952667     0.9320        0.9320     0.9320  0.992414
# 2   3.0    0.948000     0.9180        0.9180     0.9180  0.992350
# 3   4.0    0.948667     0.9220        0.9220     0.9220  0.991328
# 4   5.0    0.955333     0.9080        0.9080     0.9080  0.983635
# 5  Mean    0.951733     0.9204        0.9204     0.9204  0.989473

# %%
plt.barh(RFC.feature_names_in_, RFC.feature_importances_)
plt.title("RFC - Feature importances", size=15, fontweight="bold")
plt.xticks(size=15)
plt.yticks(size=12)
plt.show()

# %%
pd.DataFrame(RFC.feature_importances_, RFC.feature_names_in_)
# Out:
#                       0
# battery_power  0.077249
# blue           0.006711
# clock_speed    0.027605
# dual_sim       0.006924
# fc             0.025599
# four_g         0.005756
# int_memory     0.036704
# m_dep          0.023881
# mobile_wt      0.037736
# n_cores        0.022831
# pc             0.028437
# px_height      0.054388
# px_width       0.056586
# ram            0.484830
# sc_h           0.027014
# sc_w           0.028335
# talk_time      0.029849
# three_g        0.005895
# touch_screen   0.006980
# wifi           0.006691

# %% [markdown]
# # Hyperparameter tuning on the best performing model - K-Nearest Neighbors

# %%
from sklearn.model_selection import GridSearchCV
# yum = list(range(1,50))
# yup = list(range(1,50))
lup = [13,15,17,19,20,26,28]
params = { "n_neighbors":lup}
KNN = KNeighborsClassifier()
gscv = GridSearchCV(estimator=KNN, param_grid=params)
KNNGS = gscv.fit(xTrain, yTrain)
KNNGS.score(xTrain, yTrain)
# Out:
# 0.9593333333333334

# %%
KNNGSest = KNNGS.best_estimator_
KNNGSest
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
classificationmodel(KNNGSest)
# Out:
# Score of the training dataset: 0.9593333333333334
# Score of the testing dataset: 0.91
# Log-loss of the testing dataset: 0.2270203358344803
# ROC-AUC score of the testing dataset: 0.9909287715825311
# Matthews correlation coefficient of the testing dataset: 0.8806256719786122
#
# Classification report on Testing split:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       128
#            1       0.86      0.92      0.89       123
#            2       0.84      0.88      0.86       122
#            3       0.98      0.88      0.93       127
#
#     accuracy                           0.91       500
#    macro avg       0.91      0.91      0.91       500
# weighted avg       0.91      0.91      0.91       500

# %%
knntab1 = pd.DataFrame(columns=["TryNo","TrainScore","TestScore","PrecisionAvg","RecallAvg", "F1Avg","RocAuc", "MCC"])
knntab1.loc[len(knntab1)] = results.iloc[4]
for i in [13,15,17,19,20,26,28]:
    KNN23 = KNeighborsClassifier(n_neighbors=i)
    KNN23.fit(xTrain,yTrain)
    knntab1.loc[len(knntab1)] = [i, KNN23.score(xTrain,yTrain), KNN23.score(xTest,yTest), precision_score(y_true=yTest, y_pred=KNN23.predict(xTest), average="macro"), recall_score(y_true=yTest, y_pred=KNN23.predict(xTest), average='macro'), f1_score(y_true=yTest, y_pred=KNN23.predict(xTest), average="macro"),roc_auc_score(yTest, KNN23.predict_proba(xTest), multi_class="ovr"), matthews_corrcoef(yTest, KNN23.predict(xTest))]

# %%
knntab1
# Out:
#   TryNo TrainScore TestScore PrecisionAvg RecallAvg     F1Avg    RocAuc  \
# 0   NaN      0.954     0.916     0.915621  0.915608  0.915306  0.989084
# 1  13.0   0.955333     0.916     0.917153  0.915535  0.915598  0.990552
# 2  15.0   0.956667     0.908     0.909499  0.907595   0.90772  0.990799
# 3  17.0   0.959333      0.91     0.912127  0.909644    0.9099  0.990929
# 4  19.0   0.955333     0.914     0.916336  0.913678  0.914028  0.991275
# 5  20.0      0.952     0.906     0.908803  0.905724  0.905888  0.991256
# 6  26.0   0.944667       0.9     0.902124  0.899513  0.899648  0.991101
# 7  28.0      0.942     0.904     0.905661  0.903546   0.90372  0.991109
#
#         MCC
# 0  0.888038
# 1  0.888459
# 2  0.877857
# 3  0.880626
# 4  0.885954
# 5  0.875503
# 6  0.867371
# 7  0.872533
