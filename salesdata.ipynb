# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 30)

# %%
data = pd.read_csv("C://Kiki/python_tutorial/train.csv")
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
data.columns = [column.lower().replace(" ","_").replace("-","_") for column in data.columns]

# %%
data.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    postal_code region       product_id         category sub_category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9800 non-null   int64
#  1   order_id       9800 non-null   object
#  2   order_date     9800 non-null   object
#  3   ship_date      9800 non-null   object
#  4   ship_mode      9800 non-null   object
#  5   customer_id    9800 non-null   object
#  6   customer_name  9800 non-null   object
#  7   segment        9800 non-null   object
#  8   country        9800 non-null   object
#  9   city           9800 non-null   object
#  10  state          9800 non-null   object
#  11  postal_code    9789 non-null   float64
#  12  region         9800 non-null   object
#  13  product_id     9800 non-null   object
#  14  category       9800 non-null   object
#  15  sub_category   9800 non-null   object
#  16  product_name   9800 non-null   object
#  17  sales          9800 non-null   float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
data.describe()
# Out:
#             row_id   postal_code         sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
data.isna().sum()
# Out:
# row_id            0
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_id       0
# customer_name     0
# segment           0
# country           0
# city              0
# state             0
# postal_code      11
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# dtype: int64

# %%
data[["customer_id","country","city","state","postal_code","region"]][data["postal_code"].isna()].head()
# Out:
#      customer_id        country        city    state  postal_code region
# 2234    QJ-19255  United States  Burlington  Vermont          NaN   East
# 5274    SV-20785  United States  Burlington  Vermont          NaN   East
# 8798    VM-21685  United States  Burlington  Vermont          NaN   East
# 9146    CB-12535  United States  Burlington  Vermont          NaN   East
# 9147    CB-12535  United States  Burlington  Vermont          NaN   East

# %%
# leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
data["postal_code"][(data["city"] == "Burlington") & (data["state"] == "Vermont")] = 5401
data["postal_code"] = data["postal_code"].astype("int").astype("str").str.zfill(5)
data[["customer_id","country","city","state","postal_code","region"]][(data["city"] == "Burlington") & (data["state"] == "Vermont")].head()
# Out:
#      customer_id        country        city    state postal_code region
# 2234    QJ-19255  United States  Burlington  Vermont       05401   East
# 5274    SV-20785  United States  Burlington  Vermont       05401   East
# 8798    VM-21685  United States  Burlington  Vermont       05401   East
# 9146    CB-12535  United States  Burlington  Vermont       05401   East
# 9147    CB-12535  United States  Burlington  Vermont       05401   East

# %%
data[["order_date","ship_date"]] = data[["order_date","ship_date"]].astype("datetime64[ns]")
data["order_date"] = data["order_date"].dt.strftime("%d-%m-%Y")
data["ship_date"] = data["ship_date"].dt.strftime("%d-%m-%Y")
data[["order_date","ship_date"]] = data[["order_date","ship_date"]].astype("datetime64[ns]")
data["time_shipped"] = data["ship_date"] - data["order_date"]

# %%
data["weekday"] = data["order_date"].dt.day_name()
data["day"] = data["order_date"].dt.day
data["month"] = data["order_date"].dt.month_name()
data["year"] = data["order_date"].dt.year
data.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#   postal_code region       product_id         category sub_category  \
# 0       42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420  South  FUR-CH-10000454        Furniture       Chairs
# 2       90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311  South  FUR-TA-10000577        Furniture       Tables
# 4       33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales time_shipped  \
# 0                  Bush Somerset Collection Bookcase  261.9600       3 days
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400       3 days
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200       4 days
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775       7 days
# 4                     Eldon Fold 'N Roll Cart System   22.3680       7 days
#
#      weekday  day     month  year
# 0  Wednesday    8  November  2017
# 1  Wednesday    8  November  2017
# 2     Monday   12      June  2017
# 3    Tuesday   11   October  2016
# 4    Tuesday   11   October  2016

# %%
data.dtypes
# Out:
# row_id                     int64
# order_id                  object
# order_date        datetime64[ns]
# ship_date         datetime64[ns]
# ship_mode                 object
# customer_id               object
# customer_name             object
# segment                   object
# country                   object
# city                      object
# state                     object
# postal_code               object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                    float64
# time_shipped     timedelta64[ns]
# weekday                   object
# day                        int64
# month                     object
# year                       int64
# dtype: object

# %%
plt.rcParams["figure.figsize"] = (10,4)
plt.rcParams["axes.titlesize"] = 15
plt.rcParams["axes.titleweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"

# %%
zz = sns.histplot(x="sales",data=data,bins=10)
zz.bar_label(zz.containers[0])
plt.xticks(rotation=45)
plt.title(f"Histogram of sales")
plt.show()

# %%
zz = sns.lineplot(x="order_date",y="sales",data=data[data["year"] == 2018],hue="category")
plt.xticks(rotation=45)
plt.title(f"Number of products sold per day per category")
plt.show()

# %%
for i in ["day","weekday","month","year"]:
    zz = sns.countplot(x=i,data=data,palette="magma",order=data.groupby(i)["order_id"].count().reset_index().sort_values(by="order_id",ascending=False)[i])
    zz.bar_label(zz.containers[0])
    plt.xticks(fontsize=15)
    plt.title(f"Total number of sales per {i}")
    plt.xticks(rotation=45)
    plt.show()

# %%
for i in ["category","segment","ship_mode","region"]:
    zz = sns.countplot(x=i,data=data,palette="magma",order=data.groupby(i)["order_id"].count().reset_index().sort_values(by="order_id",ascending=False)[i])
    zz.bar_label(zz.containers[0])
    plt.xticks(fontsize=12, rotation=45)
    plt.title(f"Total number of sales per {i}")
    plt.show()

# %%
data.groupby("sub_category").agg(sales_count=("row_id","count"),revenue=("sales","sum"),average=("sales","mean"))
# Out:
#               sales_count      revenue      average
# sub_category
# Accessories           756  164186.7000   217.178175
# Appliances            459  104618.4030   227.926804
# Art                   785   26705.4100    34.019631
# Binders              1492  200028.7850   134.067550
# Bookcases             226  113813.1987   503.598224
# Chairs                607  322822.7310   531.833165
# Copiers                66  146248.0940  2215.880212
# Envelopes             248   16128.0460    65.032444
# Fasteners             214    3001.9600    14.027850
# Furnishings           931   89212.0180    95.823865
# Labels                357   12347.7260    34.587468
# Machines              115  189238.6310  1645.553313
# Paper                1338   76828.3040    57.420257
# Phones                876  327782.4480   374.180877
# Storage               832  219343.3920   263.633885
# Supplies              184   46420.3080   252.284283
# Tables                314  202810.6280   645.893720

# %%
for i in sorted(data["year"].unique()):
    zz = sns.countplot(x="sub_category",data=data[data["year"] == i],order=data[data["year"] == i].groupby("sub_category")["row_id"].count().sort_values(ascending=False).to_frame().reset_index()["sub_category"],palette="magma")
    zz.bar_label(zz.containers[0])
    plt.xticks(rotation=45)
    plt.title(f"Number sales per sub category - {i}")
    plt.show()

# %%
for i in sorted(data["year"].unique()):
    zz = sns.barplot(x="sub_category",y="sales",data=round(data[data["year"] == i].groupby("sub_category")["sales"].sum().to_frame().reset_index().sort_values(by="sales",ascending=False)),palette="magma")
    zz.bar_label(zz.containers[0])
    plt.xticks(rotation=45)
    plt.title(f"Revenue per sub category - {i}")
    plt.show()

# %%
data.groupby("product_id").agg(sales_count=("row_id","count"),revenue=("sales","sum"),average=("sales","mean")).sort_values(by="sales_count",ascending=False).head(10)
# Out:
#                  sales_count    revenue     average
# product_id
# OFF-PA-10001970           19   2167.348  114.070947
# TEC-AC-10003832           18  11203.756  622.430889
# FUR-FU-10004270           16    426.560   26.660000
# TEC-AC-10003628           15   1409.530   93.968667
# FUR-CH-10002647           15   3641.274  242.751600
# TEC-AC-10002049           15  13756.536  917.102400
# FUR-CH-10002880           14   5436.158  388.297000
# OFF-BI-10001524           14    780.456   55.746857
# OFF-PA-10002377           14   1004.652   71.760857
# OFF-BI-10004632           14   5535.593  395.399500

# %%
for i in sorted(data["year"].unique()):
    zz = sns.barplot(x="product_id",y="sales",data=data[data["year"] == i].groupby("product_id")["sales"].sum().to_frame().reset_index().sort_values(by="sales",ascending=False).head(10),palette="magma")
    zz.bar_label(zz.containers[0])
    plt.xticks(rotation=45)
    plt.title(f"Top 10 products with the most revenue - {i}")
    plt.show()

# %%
# BEST CITY PER CATEGORY
data.groupby(["city","category"])["sales"].sum().to_frame().sort_values(by="sales",ascending=False).reset_index().drop_duplicates(subset=["category"])
# Out:
#             city         category       sales
# 0  New York City       Technology  108980.136
# 1  New York City        Furniture   74822.885
# 3  New York City  Office Supplies   68659.526

# %%
best_per_category = round(data.groupby(["city","sub_category"])["sales"].sum().to_frame().sort_values(by="sales",ascending=False).reset_index().drop_duplicates(subset=["sub_category"]))
best_per_category["city_category"] = best_per_category["sub_category"] + " - " + best_per_category["city"]

zz = sns.barplot(x="city_category",y="sales",data=best_per_category,palette="magma")
zz.bar_label(zz.containers[0])
plt.xticks(rotation=45)
plt.title(f"Best performing cities per sub_category")
plt.show()

# %%
# BEST REVENUE PER DAY
data.groupby("order_date").agg(best_revenue=("sales","sum"),count=("sales","count")).sort_values(by="best_revenue",ascending=False)
# Out:
#             best_revenue  count
# order_date
# 2015-03-18     28106.716     11
# 2017-10-02     18452.972      7
# 2018-10-22     15158.877     12
# 2018-03-23     14816.068      8
# 2015-09-08     14228.428     27
# ...                  ...    ...
# 2015-10-01         4.710      1
# 2015-06-24         4.272      1
# 2015-01-28         3.928      1
# 2018-07-12         3.816      1
# 2016-07-19         2.025      1
#
# [1230 rows x 2 columns]

# %%
# OUTLIERS?
for i in data["category"].unique():
    sns.boxplot(x="sales",data=data[data["category"] == i])
    plt.title(i)
    plt.show()

# %%
data[(data["category"] == "Office Supplies") & (data["sales"] > data["sales"][data["category"] == "Office Supplies"].quantile(0.99))].head()
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 353      354  CA-2017-129714 2017-09-01 2017-09-03     First Class
# 509      510  CA-2016-145352 2016-03-16 2016-03-22  Standard Class
# 994      995  CA-2015-117639 2015-05-21 2015-05-25  Standard Class
# 1250    1251  CA-2018-115602 2018-12-18 2018-12-24  Standard Class
# 1711    1712  CA-2018-123491 2018-10-30 2018-11-05  Standard Class
#
#      customer_id         customer_name      segment        country  \
# 353     AB-10060       Adam Bellavance  Home Office  United States
# 509     CM-12385  Christopher Martinez     Consumer  United States
# 994     MW-18235      Mitch Willingham    Corporate  United States
# 1250    DJ-13630           Doug Jacobs     Consumer  United States
# 1711    JK-15205          Jamie Kunitz     Consumer  United States
#
#                 city       state postal_code region       product_id  \
# 353    New York City    New York       10009   East  OFF-BI-10004995
# 509          Atlanta     Georgia       30318  South  OFF-BI-10003527
# 994   Virginia Beach    Virginia       23464  South  OFF-BI-10003925
# 1250   New York City    New York       10009   East  OFF-AP-10000891
# 1711   San Francisco  California       94122   West  OFF-AP-10002684
#
#              category sub_category  \
# 353   Office Supplies      Binders
# 509   Office Supplies      Binders
# 994   Office Supplies      Binders
# 1250  Office Supplies   Appliances
# 1711  Office Supplies   Appliances
#
#                                            product_name     sales  \
# 353           GBC DocuBind P400 Electric Binding System  4355.168
# 509   Fellowes PB500 Electric Punch Plastic Comb Bin...  6354.950
# 994         Fellowes PB300 Plastic Comb Binding Machine  2715.930
# 1250  Kensington 7 Outlet MasterPiece HOMEOFFICE Pow...  1704.560
# 1711  Acco 7-Outlet Masterpiece Power Center, Wihtou...  1702.120
#
#      time_shipped    weekday  day      month  year
# 353        2 days     Friday    1  September  2017
# 509        6 days  Wednesday   16      March  2016
# 994        4 days   Thursday   21        May  2015
# 1250       6 days    Tuesday   18   December  2018
# 1711       6 days    Tuesday   30    October  2018

# %%
best_states = data[data["year"] == 2018].groupby("state")["sales"].sum().sort_values(ascending=False).reset_index().head(10)["state"].unique()
best_states

for i in best_states:
    zz = sns.barplot(x="product_id",y="sales",data=data[data["state"] == i].groupby("product_id")["sales"].sum().to_frame().reset_index().sort_values(by="sales",ascending=False).head(10),palette="magma")
    zz.bar_label(zz.containers[0])
    plt.xticks(rotation=45)
    plt.title(f"Revenue per top 10 best products in 2018 - {i}")
    plt.show()

# %%
# MOST PRODUCTS BOUGHT PER CUSTOMER
data.groupby(["customer_name","customer_id"])["order_id"].count().to_frame().reset_index().sort_values(by="order_id",ascending=False).head(10)
# Out:
#            customer_name customer_id  order_id
# 787        William Brown    WB-21850        35
# 502         Matt Abelman    MA-17560        34
# 595           Paul Prost    PP-18955        34
# 387             John Lee    JL-15835        33
# 391     Jonathan Doherty    JD-15895        32
# 689          Seth Vernon    SV-20365        32
# 145  Chloris Kastensmidt    CK-12205        32
# 791     Zuschuss Carroll    ZC-21910        31
# 259           Emily Phan    EP-13915        31
# 60        Arthur Prichep    AP-10915        31

# %%
zz = sns.countplot(x="product_id",data=data[data["customer_id"] == "WB-21850"])
zz.bar_label(zz.containers[0])
plt.xticks(rotation=45)
plt.title(f"Products of the customer with the most products bought - William Brown")
plt.show()

# %%
# MOST UNIQUE ORDERS PER CUSTOMER
data.drop_duplicates(subset=["order_id"]).groupby(["customer_name","customer_id"])["order_id"].count().to_frame().reset_index().sort_values(by="order_id",ascending=False)
# Out:
#            customer_name customer_id  order_id
# 259           Emily Phan    EP-13915        17
# 145  Chloris Kastensmidt    CK-12205        13
# 381           Joel Eaton    JE-15745        13
# 791     Zuschuss Carroll    ZC-21910        13
# 586      Patrick Gardner    PG-18820        13
# ..                   ...         ...       ...
# 455         Lela Donovan    LD-16855         1
# 741        Theresa Coyne    TC-21145         1
# 584    Patricia Hirasaki    PH-18790         1
# 545      Mitch Gastineau    MG-18205         1
# 53     Anthony O'Donnell    AO-10810         1
#
# [793 rows x 3 columns]

# %%
zz = sns.countplot(x="product_id",data=data[data["customer_id"] == "EP-13915"])
zz.bar_label(zz.containers[0])
plt.xticks(rotation=45)
plt.title(f"Products of the customer  with the most unique orders - Emily Phan")
plt.show()

# %%
# TIME TO SHIP A PRODUCT PER CATEGORY
time_to_ship = pd.DataFrame()

for i in data["category"].unique():
    ship = data[["category","time_shipped"]][data["category"] == i].value_counts(normalize=True).to_frame().reset_index().rename(columns={0: "percentage"})
    time_to_ship = pd.concat([time_to_ship,ship])

time_to_ship
# Out:
#           category time_shipped  percentage
# 0        Furniture       4 days    0.282483
# 1        Furniture       5 days    0.222810
# 2        Furniture       2 days    0.142445
# 3        Furniture       6 days    0.111646
# 4        Furniture       3 days    0.086622
# 5        Furniture       7 days    0.061598
# 6        Furniture       0 days    0.055342
# 7        Furniture       1 days    0.037055
# 0  Office Supplies       4 days    0.275004
# 1  Office Supplies       5 days    0.219496
# 2  Office Supplies       2 days    0.126248
# 3  Office Supplies       6 days    0.123202
# 4  Office Supplies       3 days    0.103232
# 5  Office Supplies       7 days    0.064139
# 6  Office Supplies       0 days    0.051955
# 7  Office Supplies       1 days    0.036724
# 0       Technology       4 days    0.279095
# 1       Technology       5 days    0.213458
# 2       Technology       2 days    0.139548
# 3       Technology       6 days    0.115830
# 4       Technology       3 days    0.103696
# 5       Technology       7 days    0.059570
# 6       Technology       0 days    0.050745
# 7       Technology       1 days    0.038058

# %%
# AVERAGE ORDER VALUE PER CATEGORY
for i in data["category"].unique():
    print(f"Average order value of category {i}:")
    print(data[data["category"] == i].groupby("order_id")["sales"].mean().mean(),"\n")
# Out:
# Average order value of category Furniture:
# 348.9624277504343
#
# Average order value of category Office Supplies:
# 117.93562804031298
#
# Average order value of category Technology:
# 450.0228974105771

# %%
# WHICH SUB_CATEGORIES TAKE 7 DAYS TO SHIP MOST OFTEN
data["sub_category"][data["time_shipped"] == "7 days"].value_counts().to_frame()
# Out:
#              sub_category
# Binders               111
# Paper                  66
# Art                    60
# Furnishings            55
# Phones                 52
# Storage                44
# Accessories            42
# Chairs                 39
# Appliances             28
# Tables                 22
# Labels                 21
# Supplies               18
# Fasteners              16
# Envelopes              15
# Bookcases              12
# Machines               10
# Copiers                 4

# %%
data1 = data
data1["product_name"] = data1["product_name"].str.replace(",","")

duplicated = data1[data1["order_id"].duplicated(keep=False)]
duplicated.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 5       6  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
#
#      customer_name   segment        country             city       state  \
# 0      Claire Gute  Consumer  United States        Henderson    Kentucky
# 1      Claire Gute  Consumer  United States        Henderson    Kentucky
# 3   Sean O'Donnell  Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell  Consumer  United States  Fort Lauderdale     Florida
# 5  Brosina Hoffman  Consumer  United States      Los Angeles  California
#
#   postal_code region       product_id         category sub_category  \
# 0       42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420  South  FUR-CH-10000454        Furniture       Chairs
# 3       33311  South  FUR-TA-10000577        Furniture       Tables
# 4       33311  South  OFF-ST-10000760  Office Supplies      Storage
# 5       90032   West  FUR-FU-10001487        Furniture  Furnishings
#
#                                         product_name     sales time_shipped  \
# 0                  Bush Somerset Collection Bookcase  261.9600       3 days
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs ...  731.9400       3 days
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775       7 days
# 4                     Eldon Fold 'N Roll Cart System   22.3680       7 days
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600       5 days
#
#      weekday  day     month  year
# 0  Wednesday    8  November  2017
# 1  Wednesday    8  November  2017
# 3    Tuesday   11   October  2016
# 4    Tuesday   11   October  2016
# 5    Tuesday    9      June  2015

# %%
duplicated["grouped"] = duplicated.groupby("order_id")["product_name"].transform(lambda x: ",".join(x))

df = duplicated[["order_id","grouped"]].drop_duplicates()

# %%
# WHICH PRODUCTS WERE SOLD TOGETHER THE MOST?

from collections import Counter
from itertools import combinations

count = Counter()

for row in df["grouped"]:
    row_list = row.split(",")
    count.update(Counter(combinations(row_list,3)))

pairs = count.most_common(10)

# %%
for key, value in pairs:
    print(key,value)
# Out:
# ('Sabrent 4-Port USB 2.0 Hub', 'Xerox 1881', 'GBC DocuBind P400 Electric Binding System') 2
# ('GBC ProClick 150 Presentation Binding System', 'Imation\xa0Secure+ Hardware Encrypted USB 2.0\xa0Flash Drive; 16GB', 'Woodgrain Magazine Files by Perma') 2
# ('Wilson Jones Turn Tabs Binder Tool for Ring Binders', 'Maxell\xa0iVDR EX 500GB Cartridge', 'Adjustable Depth Letter/Legal Cart') 2
# ('Global Leather Highback Executive Chair with Pneumatic Height Adjustment Black', 'Zipper Ring Binder Pockets', 'G.E. Halogen Desk Lamp Bulbs') 2
# ('Newell 344', 'Memorex Micro Travel Drive 16 GB', 'Wirebound Four 2-3/4 x 5 Forms per Page 400 Sets per Book') 2
# ('Newell 344', 'Memorex Micro Travel Drive 16 GB', 'Elite 5" Scissors') 2
# ('Newell 344', 'Memorex Micro Travel Drive 16 GB', 'Staple-based wall hangings') 2
# ('Newell 344', 'Memorex Micro Travel Drive 16 GB', 'Eldon Image Series Desk Accessories Burgundy') 2
# ('Newell 344', 'Memorex Micro Travel Drive 16 GB', 'DAX Two-Tone Silver Metal Document Frame') 2
# ('Memorex Micro Travel Drive 16 GB', 'Wirebound Four 2-3/4 x 5 Forms per Page 400 Sets per Book', 'Elite 5" Scissors') 2

# %%
states = data.groupby("state").agg(revenue=("sales","sum"), products_sold=("sales","count")).reset_index()

states["percentage"] = (states["products_sold"].apply(lambda x: x/states["products_sold"].sum()))*100
states.head()
# Out:
#         state      revenue  products_sold  percentage
# 0     Alabama   19510.6400             61    0.622449
# 1     Arizona   35272.6570            223    2.275510
# 2    Arkansas   11678.1300             60    0.612245
# 3  California  446306.4635           1946   19.857143
# 4    Colorado   31841.5980            179    1.826531

# %%
from selenium.webdriver import Chrome 
from bs4 import BeautifulSoup 
import time

url = "https://worldpopulationreview.com/states"
driver = Chrome(executable_path="C://Kiki/chromedriver.exe")
driver.get(url)
time.sleep(5)

# %%
soup = BeautifulSoup(driver.page_source,"html.parser")
driver.quit()

# %%
rows = soup.find("table",class_="jsx-364991517 table is-striped is-hoverable is-fullwidth tp-table-body is-narrow").tbody.find_all("tr")

# %%
states_scraped = pd.DataFrame(columns=["state","population_2022","percentage_usa"])

for i in range(0,len(rows)):
    states_scraped.loc[len(states_scraped)] = [rows[i].find("a").text.strip(), rows[i].find_all("td")[2].text.strip(),rows[i].find_all("td")[7].text.strip()]

states_scraped.head(5)
# Out:
#           state population_2022 percentage_usa
# 0    California      39,995,077         11.93%
# 1         Texas      29,945,493          8.93%
# 2       Florida      22,085,563          6.59%
# 3      New York      20,365,879          6.07%
# 4  Pennsylvania      13,062,764          3.90%

# %%
states_merged = pd.merge(left=states,right=states_scraped,left_on="state",right_on="state",how="inner")

states_merged["percentage_usa"] = states_merged["percentage_usa"].str.replace("%","").astype("float")
states_merged["percentage_diff"] = states_merged["percentage"] - states_merged["percentage_usa"]

states_merged.head()
# Out:
#         state      revenue  products_sold  percentage population_2022  \
# 0     Alabama   19510.6400             61    0.622449       5,073,187
# 1     Arizona   35272.6570            223    2.275510       7,303,398
# 2    Arkansas   11678.1300             60    0.612245       3,030,646
# 3  California  446306.4635           1946   19.857143      39,995,077
# 4    Colorado   31841.5980            179    1.826531       5,922,618
#
#    percentage_usa  percentage_diff
# 0            1.51        -0.887551
# 1            2.18         0.095510
# 2            0.90        -0.287755
# 3           11.93         7.927143
# 4            1.77         0.056531

# %%
plt.figure(figsize=(15,5))
sns.barplot(x="state",y="percentage_diff",data=states_merged)
zz = sns.barplot(x="state",y="percentage_diff",data=states_merged)
plt.xticks(rotation=90)
plt.title(f"Over/under performing States - {i}")
plt.show()
